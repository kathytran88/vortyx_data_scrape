# %%
import pandas as pd 
import numpy as np 

df1 = pd.read_excel('pull3-aug12/Pull 3.xlsx')
df2 = pd.read_excel('pull2-aug11/final/NY Google API Pull 1+2.xlsx')

# %%
df1.head()
# Out:
#    Unnamed: 0                                title  \
# 0           0               Manasquan Dry Cleaners
# 1           1                 Main Street Cleaners
# 2           2                    Atlantic Cleaners
# 3           3          Pat the Tailor Dry Cleaners
# 4           4  Surf Suds Laundromat Point Pleasant
#
#                                             placeURL  \
# 0  https://www.google.com/maps/place/?q=place_id:...
# 1  https://www.google.com/maps/place/?q=place_id:...
# 2  https://www.google.com/maps/place/?q=place_id:...
# 3  https://www.google.com/maps/place/?q=place_id:...
# 4  https://www.google.com/maps/place/?q=place_id:...
#
#                            website  rating  reviewCount category  \
# 0                              NaN     5.0          5.0  cleaner
# 1                              NaN     5.0          4.0  cleaner
# 2                              NaN     4.3          6.0  cleaner
# 3   http://www.patthetailornj.com/     4.3         24.0  cleaner
# ...

# %%
df2.head()
# Out:
#    Unnamed: 0                                              title  \
# 0           0  tecHangouts LLC - Website & Mobile App Develop...
# 1           1                                     A Uno New York
# 2           2                                       Y&D Nail Spa
# 3           3                          24 Hr. Emergency Plumbing
# 4           4                                    31-A Laundromat
#
#                                             placeURL  \
# 0  https://www.google.com/maps/place/?q=place_id:...
# 1  https://www.google.com/maps/place/A+Uno+New+Yo...
# 2  https://www.google.com/maps/place/Y%26D+Nail+S...
# 3                                                NaN
# 4  https://www.google.com/maps/place/31-A+Laundro...
#
#                                  website  rating  reviewCount  \
# 0               https://techangouts.com/     5.0          3.0
# 1                http://aunonewyork.com/     4.5         11.0
# ...

# %%
df = pd.concat([df1, df2], ignore_index = True)
df.shape
# Out:
# (2808, 11)

# %%
df = df.drop_duplicates(keep='first')
df.shape
# Out:
# (2808, 11)

# %%
df = df.drop_duplicates(subset = 'phoneNumber', keep='first')
df.shape
# Out:
# (2654, 11)

# %%
df.head()
# Out:
#    Unnamed: 0                                title  \
# 0           0               Manasquan Dry Cleaners
# 1           1                 Main Street Cleaners
# 2           2                    Atlantic Cleaners
# 3           3          Pat the Tailor Dry Cleaners
# 4           4  Surf Suds Laundromat Point Pleasant
#
#                                             placeURL  \
# 0  https://www.google.com/maps/place/?q=place_id:...
# 1  https://www.google.com/maps/place/?q=place_id:...
# 2  https://www.google.com/maps/place/?q=place_id:...
# 3  https://www.google.com/maps/place/?q=place_id:...
# 4  https://www.google.com/maps/place/?q=place_id:...
#
#                            website  rating  reviewCount category  \
# 0                              NaN     5.0          5.0  cleaner
# 1                              NaN     5.0          4.0  cleaner
# 2                              NaN     4.3          6.0  cleaner
# 3   http://www.patthetailornj.com/     4.3         24.0  cleaner
# ...

# %%
del df['Unnamed: 0']

# %%
df.to_excel('Pull 1+2+3.xlsx')
