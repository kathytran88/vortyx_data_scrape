# %%
import time
import googlemaps
import pandas as pd
import requests
from bs4 import BeautifulSoup
from itertools import product

def miles_to_meters(miles):
    return miles * 1_609.344

def extract_email_from_website(url):
    try:
        response = requests.get(url, timeout=10)
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')
            emails = set()
            for mailto in soup.select('a[href^=mailto]'):
                emails.add(mailto.get('href').replace('mailto:', ''))
            if emails:
                return ', '.join(emails)
        return None
    except Exception as e:
        return None

def create_grid(center_lat, center_lng, radius_miles, step_miles):
    step = miles_to_meters(step_miles)
    radius = miles_to_meters(radius_miles)
    lat_steps = int(2 * radius / step)
    lng_steps = int(2 * radius / step)
    lat_range = [center_lat + i * step / 111000 for i in range(-lat_steps, lat_steps + 1)]
    lng_range = [center_lng + i * step / (111000 * abs(center_lat)) for i in range(-lng_steps, lng_steps + 1)]
    return list(product(lat_range, lng_range))

def map_category(place_types):
    # Example mapping for place types to categories
    type_map = {
        'computer_store': 'Computer Store',
        'electronics_store': 'Electronics Store',
        'computer_repair': 'Computer Repair Service',
        'point_of_interest': 'Point of Interest',
        'establishment': 'Establishment'
    }
    for place_type in place_types:
        if place_type in type_map:
            return type_map[place_type]
    return 'Other'  # Fallback category

API_KEY = 'AIzaSyBY_IAnmIfTHWsjHTIjz-4nmOqkFdRY0SM'  
map_client = googlemaps.Client(API_KEY)

center_lat, center_lng = 42.8864, -78.8784  # Buffalo
radius_miles = 50  # Total search radius 
step_miles = 10  # Step size for the grid
grid = create_grid(center_lat, center_lng, radius_miles, step_miles)

# List of search queries
search_queries = [
    'small dry cleaner',
    'small spa',
    'small clothing',
    'small salon',
    'small gym',
    'small pet',
    'small software technology',
    'small shop',
    'small clinic',
    'small cable company',
    'small ladder scaffolding',
    'small skin care',
    'small laser hair removal',
    'small beauty',
    'small car wash',
    'small towing',
    'small barber',
    'small massage',
    'small HVAC',
    'small plumbing',
    'small childcare',
    'small art gallery',
    'small casino',
    'small nightclub',
    'small repair',
    'small security',
    'small staffing agency'
]

all_detailed_businesses = []

# Set the limit for the number of results per query
result_limit = 100

for search_string in search_queries:
    business_list = []
    
    for (lat, lng) in grid:
        if len(business_list) >= result_limit:
            break
        
        response = map_client.places_nearby(
            location=(lat, lng),
            keyword=search_string,
            radius=miles_to_meters(step_miles)
        )
        
        business_list.extend(response.get('results'))
        next_page_token = response.get('next_page_token')
        
        while next_page_token and len(business_list) < result_limit:
            time.sleep(2)
            response = map_client.places_nearby(
                location=(lat, lng),
                keyword=search_string,
                radius=miles_to_meters(step_miles),
                page_token=next_page_token
            )
            business_list.extend(response.get('results'))
            next_page_token = response.get('next_page_token')
            
            if len(business_list) >= result_limit:
                break
    
    # Fetch detailed information for each business and collect in the specified order
    for business in business_list:
        place_id = business.get('place_id')
        details = map_client.place(place_id=place_id)
        result = details.get('result', {})
        
        title = result.get('name')
        placeURL = 'https://www.google.com/maps/place/?q=place_id:' + place_id
        website = result.get('website')
        rating = result.get('rating')
        reviewCount = result.get('user_ratings_total')
        category = map_category(result.get('types', [])) if 'types' in result else 'Other'
        address = result.get('formatted_address')
        phoneNumber = result.get('formatted_phone_number')
        email = extract_email_from_website(website) if website else None
        
        business_info = {
            'title': title,
            'placeURL': placeURL,
            'website': website,
            'rating': rating,
            'reviewCount': reviewCount,
            'category': search_string.split(' ')[-1],  # Extract category from search string
            'address': address,
            'phoneNumber': phoneNumber,
            'searchQuery': search_string,
            'email': email
        }
        
        all_detailed_businesses.append(business_info)

df = pd.DataFrame(all_detailed_businesses)
print('done')
# Out:
# done

# %%
all_detailed_businesses.append(business_info)
df = pd.DataFrame(all_detailed_businesses)

# %%
''' 
For small HVAC/roofing/plumbing also maybe add in cable, window cleaning, ladder scaffolding
For small medical spa/self care maybe also add in laser hair removal clinic, facial clinic, nail salon
For small laundromat maybe also add in dry cleaning 

Radius of Search: The total search radius is set to 20 miles from the center. This means that the code will collect businesses within a radius of 20 miles from the initial center point.

Step Size: The grid is divided into smaller cells with a 5-mile step size. This means that the search area is divided into a grid where each cell is roughly 5 miles by 5 miles, and the Google Places API is queried at each of these grid points.
'''
# Out:
# ' \nFor small HVAC/roofing/plumbing also maybe add in cable, window cleaning, ladder scaffolding\nFor small medical spa/self care maybe also add in laser hair removal clinic, facial clinic, nail salon\nFor small laundromat maybe also add in dry cleaning \n\nRadius of Search: The total search radius is set to 20 miles from the center. This means that the code will collect businesses within a radius of 20 miles from the initial center point.\n\nStep Size: The grid is divided into smaller cells with a 5-mile step size. This means that the search area is divided into a grid where each cell is roughly 5 miles by 5 miles, and the Google Places API is queried at each of these grid points.\n'

# %%
df.head()
# Out:
#                                              title  \
# 0                                West Side Laundry
# 1  MC'S Power Washing & Soft Washing Services LLC.
# 2                            Keystone Ace Hardware
# 3                                   Dollar General
# 4                                West Side Laundry
#
#                                             placeURL  \
# 0  https://www.google.com/maps/place/?q=place_id:...
# 1  https://www.google.com/maps/place/?q=place_id:...
# 2  https://www.google.com/maps/place/?q=place_id:...
# 3  https://www.google.com/maps/place/?q=place_id:...
# 4  https://www.google.com/maps/place/?q=place_id:...
#
#                                              website  rating  reviewCount  \
# 0                                               None     4.6          7.0
# 1                                               None     5.0         17.0
# 2  http://www.acehardware.com/store-details/16368...     4.4        131.0
# 3  https://www.dollargeneral.com/store-directory/...     4.0        193.0
# 4                                               None     4.6          7.0
#
#   category                                      address     phoneNumber  \
# 0  cleaner  107 Montmorenci Ave, Ridgway, PA 15853, USA            None
# 1  cleaner            Maple Ave, Ridgway, PA 15853, USA  (814) 594-9047
# 2  cleaner           14 Main St, Ridgway, PA 15853, USA  (814) 773-5055
# 3  cleaner          249 Main St, Ridgway, PA 15853, USA  (814) 788-2669
# 4  cleaner  107 Montmorenci Ave, Ridgway, PA 15853, USA            None
#
#          searchQuery email
# 0  small dry cleaner  None
# 1  small dry cleaner  None
# 2  small dry cleaner  None
# 3  small dry cleaner  None
# 4  small dry cleaner  None

# %%
df.shape
# Out:
# (2767, 10)

# %%
df = df.drop_duplicates(keep='first')
df.shape
# Out:
# (324, 10)

# %%
df = df.drop_duplicates(subset='phoneNumber', keep='first')
df.shape
# Out:
# (233, 10)

# %%
for index, phone in df['phoneNumber'].items():
    if pd.notnull(phone):

        new_phone = ''
        for character in phone:
            if character.isnumeric():
                new_phone += character

        df.at[index, 'phoneNumber'] = new_phone 

for index, phone in df['phoneNumber'].items():
    if pd.notnull(phone):
        df.at[index, 'phoneNumber'] = '+1 ' + phone[:3] + '-' + phone[3:6] + '-' + phone[6:]

# %%
df.to_excel('pull4b.xlsx', index=True) ###############

# %%
df.head()
# Out:
#                                               title  \
# 0                                 West Side Laundry
# 1   MC'S Power Washing & Soft Washing Services LLC.
# 2                             Keystone Ace Hardware
# 3                                    Dollar General
# 22                                    Family Dollar
#
#                                              placeURL  \
# 0   https://www.google.com/maps/place/?q=place_id:...
# 1   https://www.google.com/maps/place/?q=place_id:...
# 2   https://www.google.com/maps/place/?q=place_id:...
# 3   https://www.google.com/maps/place/?q=place_id:...
# 22  https://www.google.com/maps/place/?q=place_id:...
#
#                                               website  rating  reviewCount  \
# 0                                                None     4.6          7.0
# 1                                                None     5.0         17.0
# 2   http://www.acehardware.com/store-details/16368...     4.4        131.0
# 3   https://www.dollargeneral.com/store-directory/...     4.0        193.0
# 22  https://www.familydollar.com/locations/pa/ridg...     4.5         20.0
#
#    category                                      address      phoneNumber  \
# 0   cleaner  107 Montmorenci Ave, Ridgway, PA 15853, USA             None
# 1   cleaner            Maple Ave, Ridgway, PA 15853, USA  +1 814-594-9047
# 2   cleaner           14 Main St, Ridgway, PA 15853, USA  +1 814-773-5055
# 3   cleaner          249 Main St, Ridgway, PA 15853, USA  +1 814-788-2669
# 22  cleaner       102 N Broad St, Ridgway, PA 15853, USA  +1 814-389-1121
#
#           searchQuery email
# 0   small dry cleaner  None
# 1   small dry cleaner  None
# 2   small dry cleaner  None
# 3   small dry cleaner  None
# 22  small dry cleaner  None
