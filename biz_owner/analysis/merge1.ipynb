# %%
import pandas as pd 
import numpy as np 

df1 = pd.read_excel('tobemerge.xlsx')
df2 = pd.read_excel('nyc_1mile_software.xlsx')

# %%
del df1['Unnamed: 0']
del df2['Unnamed: 0']

# %%
df1.head()
# Out:
#                                                title  \
# 0                 New York Capital Technologies, LLC
# 1  ANGLER Technologies USA Inc - Development of A...
# 2                                   WCA Technologies
# 3                      Integrated Technology Systems
# 4                                        Ziggle Tech
#
#                                             placeUrl  \
# 0  https://www.google.com/maps/place/New+York+Cap...
# 1  https://www.google.com/maps/place/ANGLER+Techn...
# 2  https://www.google.com/maps/place/WCA+Technolo...
# 3  https://www.google.com/maps/place/Integrated+T...
# 4  https://www.google.com/maps/place/Ziggle+Tech/...
#
#                         website  rating  reviewCount  \
# 0    https://nycapitaltech.com/     5.0         12.0
# 1  https://www.angleritech.com/     NaN          NaN
# 2      https://www.wcatech.com/     5.0          2.0
# 3        http://www.itsnyc.com/     5.0         21.0
# ...

# %%
df2 = df2.rename(columns={'placeURL': 'placeUrl'})
df2.head()
# Out:
#                                                title  \
# 0                             Shore Technology Group
# 1                Keypress Software Development Group
# 2  Cybesion | Cybersecurity Solutions | Expert Da...
# 3                                    Gray Technology
# 4                          ShoreSite Web Designs LLC
#
#                                             placeUrl  \
# 0  https://www.google.com/maps/place/?q=place_id:...
# 1  https://www.google.com/maps/place/?q=place_id:...
# 2  https://www.google.com/maps/place/?q=place_id:...
# 3  https://www.google.com/maps/place/?q=place_id:...
# 4  https://www.google.com/maps/place/?q=place_id:...
#
#                                              website  rating  reviewCount  \
# 0               http://www.shoretechnologygroup.com/     5.0         21.0
# 1                          http://keypressgroup.com/     NaN          NaN
# 2                              https://cybesion.com/     5.0         19.0
# ...

# %%
df = pd.concat([df1, df2], ignore_index=True)
df.shape
# Out:
# (5070, 10)

# %%
df.head()
# Out:
#                                                title  \
# 0                 New York Capital Technologies, LLC
# 1  ANGLER Technologies USA Inc - Development of A...
# 2                                   WCA Technologies
# 3                      Integrated Technology Systems
# 4                                        Ziggle Tech
#
#                                             placeUrl  \
# 0  https://www.google.com/maps/place/New+York+Cap...
# 1  https://www.google.com/maps/place/ANGLER+Techn...
# 2  https://www.google.com/maps/place/WCA+Technolo...
# 3  https://www.google.com/maps/place/Integrated+T...
# 4  https://www.google.com/maps/place/Ziggle+Tech/...
#
#                         website  rating  reviewCount  \
# 0    https://nycapitaltech.com/     5.0         12.0
# 1  https://www.angleritech.com/     NaN          NaN
# 2      https://www.wcatech.com/     5.0          2.0
# 3        http://www.itsnyc.com/     5.0         21.0
# ...

# %%
df.to_excel('official1.xlsx')
