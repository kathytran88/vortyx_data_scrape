# %%
import pandas as pd 
import numpy as np 

bizbuysell = pd.read_excel('bizbuysell.xlsx')
del bizbuysell['Unnamed: 0']

bizquest = pd.read_excel('bizquest.xlsx')
del bizquest['Unnamed: 0']

# %%
bizbuysell['Email'] = np.nan
bizquest['Email'] = np.nan

# %%
bizbuysell.head()
# Out:
#                                              Company First Name Last Name  \
# 0               Access Commercial & Business Brokers        Sam     Mozeb
# 1                           Alabama Business Brokers       Brad      Owen
# 2                               TNT Business Brokers     Wyndee   Townley
# 3  Sunbelt Business Brokers and Business Brokers ...      David      Chew
# 4                                  Business Resource     Wilson    Archer
#
#         Full Name  Corporate Phone                Location            City  \
# 0       Sam Mozeb  +1 256-309-7556         Decatur,Alabama         Decatur
# 1       Brad Owen  +1 205-294-9148         Clanton,Alabama         Clanton
# 2  Wyndee Townley  +1 251-233-9942    Orange Beach,Alabama    Orange Beach
# 3      David Chew  +1 251-278-8171          Daphne,Alabama          Daphne
# 4   Wilson Archer  +1 208-870-1717  Mountain Brook,Alabama  Mountain Brook
#
#      State                                       Profile Link  Email
# ...

# %%
bizbuysell.to_excel('bizbuysell2.xlsx')
bizquest.to_excel('bizquest2.xlsx')
